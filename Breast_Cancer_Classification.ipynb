# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv("breast_cancer_data.csv")

# %%
data.head()

# %%
col_name=data.columns

# %%
col_name

# %%
y=data.diagnosis
drop_cols=['Unnamed: 32', 'id', 'diagnosis']
x=data.drop(drop_cols, axis=1)
x.head()

# %%
ax = sns.countplot(x='diagnosis', data=data, hue='diagnosis', palette='RdPu', legend=False)
B,M=y.value_counts()
print("Benign Tumours is ", B)
print("Malignant Tumours is ", M)

# %%
x.describe()

# %%
sns.set(style='whitegrid')
data=x
data_std=(data-data.mean())/data.std()
data=pd.concat([y,data_std.iloc[:,0:10]],axis=1)
data=pd.melt(data,id_vars='diagnosis',var_name='features',value_name='value')
plt.figure(figsize=(10,10))
sns.stripplot(x='features',y='value',hue='diagnosis',data=data,palette='RdPu', legend=False)
plt.xticks(rotation=45)
plt.show()

# %%
sns.set(style='whitegrid')
data=x
data_std=(data-data.mean())/data.std()
data=pd.concat([y,data_std.iloc[:,10:20]],axis=1)
data=pd.melt(data,id_vars='diagnosis',var_name='features',value_name='value')
plt.figure(figsize=(10,10))
sns.stripplot(x='features',y='value',hue='diagnosis',data=data,palette='PuRd')
plt.xticks(rotation=45)
plt.show()

# %%
sns.set(style='whitegrid')
data=x
data_std=(data-data.mean())/data.std()
data=pd.concat([y,data_std.iloc[:,20:30]],axis=1)
data=pd.melt(data,id_vars='diagnosis',var_name='features',value_name='value')
plt.figure(figsize=(10,10))
sns.stripplot(x='features',y='value',hue='diagnosis',data=data,palette='autumn')
plt.xticks(rotation=45)
plt.show()

# %%
f,ax=plt.subplots(figsize=(20,20))
sns.heatmap(x.corr(),annot=True,linewidth=0.5,fmt='.1f',ax=ax)
plt.show()

# %%
x.head()

# %%
drop_list = ['perimeter_mean','radius_mean','compactness_mean','concave points_mean',
             'radius_se','perimeter_se','radius_worst','perimeter_worst','compactness_worst',
             'concavity_worst','compactness_se','concave points_se','texture_worst','area_worst']
x1 = x.drop(drop_list ,axis = 1 )        
x1.head()

# %%
f,ax=plt.subplots(figsize=(20,20))
sns.heatmap(x1.corr(),annot=True,linewidth=0.5,fmt='.1f',ax=ax)
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(x1, y, test_size=0.2, random_state=21)

clf_rf = RandomForestClassifier(random_state=42)      
clr_rf = clf_rf.fit(x_train,y_train)

ac = accuracy_score(y_test,clf_rf.predict(x_test))
print('Accuracy is: ',ac*100)
cm = confusion_matrix(y_test,clf_rf.predict(x_test))
sns.heatmap(cm/np.sum(cm),annot=True,fmt=".2%",cmap='RdPu')
plt.show()
